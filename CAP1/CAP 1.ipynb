# %% [markdown]
# # PIL - Python Imaging Library

# %%
from PIL import Image
from pylab import *
import numpy as np

# %%
#Lendo uma imagem com o módulo Image
pil_img = Image.open('nana.png')

# %%
#Convertendo uma imagem para np.array e mostrando a imagem 
img = np.array(pil_img)
imshow(img)

# %%
# Converte a imagem pra grayscale
img_gray = Image.open('nana.png').convert('L')

# %%
# mostra a imagem
img_gray = np.array(img_gray)
imshow(img_gray)

# %%
i
# Out:
# (200, 300)

# %% [markdown]
# ## Create Thumbnails

# %% [markdown]
# Using PIL to create thumbnails is very simple. The **thumbnail()** method takes a tuple specifying the new size and converts the image to a thumbnail image with size that fits within the tuple. To create a thumbnail with longest side 128 pixels, use the method like this:

# %%
pil_img.thumbnail((128,128))

# %%
imshow(pil_img)

# %% [markdown]
# ## Copy and Paste Regions

# %% [markdown]
# Cropping a region from an images is done using the **crop()** method:

# %%
box = (100,100,400,400)
region = pil_img.crop(box)

# %% [markdown]
# The region is defined a 4-Tuple, where coordinates are (left,upper,right,lower). PIL uses a coordinate system with (0,0) in the upper left corner. The extracted region can, for example, be rotated and then put back using the **paste()** method lihe this:

# %%
region = region.transpose(Image.ROTATE_180)
pil_img.paste(region,box)

# %% [markdown]
# ## Resize and Rotate

# %% [markdown]
# To resize an image, call **resize()** with a tu8ple giving the new size:

# %%
out = pil_img.resize((128,128))

# %% [markdown]
# To rotate an image, use counterclockwise angles and **rotate()** like this:

# %%
out = pil_img.rotate(45)
imshow(out)

# %% [markdown]
# # 1.2 Matplotlib

# %% [markdown]
# ## Plotting Images, Points, and Lines

# %% [markdown]
# ALthough it is possible to create nice bar plots, pie charts, scatter plots, etc., only a few commands are needed for most computer vision purposes. Most importantly, we want to be able to show things llike interest points, correspondences, and detected objects using points and lines. Here is an example of plotting an image with a feew points and a line:

# %%
#read image to np.array
img = np.array(Image.open('nana.png'))

#plot the image
imshow(img)

#some point
x = [100,100,400,400]
y = [200,500,200,500]

#plot the points with red star-markers
#plot(x,y,'r*')

# line plot connecting the first two points
#plot(x[:2],y[:2])

#add title and show the plot
title('Plotting: Banana')
show()

# %% [markdown]
# ## Image Contours and Histograms

# %%
im = np.array(Image.open('nana.png').convert('L'))

# create a new figure
figure()
#don't use colors
gray()
#show contours with origin upper left corner
contour(im,origin='image')
axis('equal')
axis('off')

figure()
hist(im.flatten(),128)
show()

# %% [markdown]
# An image histogram is a plot showing the distribution of pixel values. A number of bins is specified for the span of values and each bin gets a count of how many pixels have values in the bin's range. The visualization of the (graylevel) image histogram is done using the **hist()** function.

# %% [markdown]
# ## Interactive Annotation

# %% [markdown]
# Sometimes users need to interact with an application, for example by marking points in an image, or you need to annotate some training data. PyLab comes with a simple function, **ginput()**, that lets you do just that. Here's a short example:

# %%
#im = np.array(Image.open('nana.png'))
#imshow(im)
#print('Please click 3 points')
#x = ginput(3)
#print('you cliked:',x)
#show()

# %% [markdown]
# ## Array Image Representation

# %%
im = np.array(Image.open('apple.jpg'))
print(im.shape)
print(im.dtype)
# Out:
# (100, 100, 3)
# uint8

# %%
new_im = np.array(Image.open('apple.jpg').convert('L'),'f')
print(new_im.shape)
print(new_im.dtype)
# Out:
# (100, 100)
# float32

# %%
imshow(new_im)
